# %% [markdown]
# # Phân chia công việc — Chapter 2 (Nhóm C)
#
# **Leader:** Duy | **Deadline:** 31/5/2026 23:59
#
# File nộp chung: `assignment_starter-2.ipynb` — mỗi người chỉ điền phần mình.

# %% [markdown]
# ## Bảng phân công
#
# | Người | Việc | Mục notebook | Trạng thái repo |
# |-------|------|--------------|------------------|
# | **Duy** | `my_dft1`, `my_dft2`, `my_idft2` | §1.1 | ✅ Duy commit (30/5) |
# | **Tuyền** | `apply_filter`, `ideal_lp`, `ideal_hp` | §1.3–1.4 | Tự làm |
# | **Trường** | `butterworth_*`, `butterworth_notch` | §1.5–1.7 | Tự làm |
# | **Nguyên** | `sobel_gradients`, `gaussian_blur`, `harris_detector` | §2.0–2.1 | Tự làm |
# | **Nhung** | `harris_laplace`, `fast_is_corner` | §2.2–2.4 | Tự làm |
# | **Quyến** | SIFT: `build_dog_pyramid`, extrema, orientation, descriptor | §3.1–3.5 | Tự làm |

# %% [markdown]
# ## Lịch
#
# | Ngày | Việc |
# |------|------|
# | **30/5** | Duy xong §1.1, push phần Duy + `phan-chia-cong-viec-ch2.ipynb` + hình `giai-thich-ch2/` |
# | **31/5** | Cả nhóm hoàn thiện phần mình → chạy full notebook không lỗi → nộp trước 23:59 |

# %% [markdown]
# ## Phụ thuộc (ai cần ai)
#
# ```
# Duy (DFT §1.1)
#   └─> Tuyền (apply_filter §1.3) — cần hiểu DFT, dùng np.fft cho lọc
#         └─> Trường (Butterworth, notch §1.5–1.7) — dùng apply_filter + freq_coords
#
# Nguyên (Sobel, Gaussian, Harris §2.0–2.1)
#   └─> Nhung (Harris-Laplace, FAST §2.2–2.4) — gọi harris_detector, gaussian_blur
#
# Quyến (SIFT §3.1–3.5) — độc lập Bài 3, dùng gaussian_blur (có thể tự convolve nếu Nguyên chưa xong)
# ```
#
# **Lưu ý:** Repo chỉ commit code từng người vào đúng § — không điền hộ.

# %% [markdown]
# ## Tài liệu
#
# - PDF: `Computer_Vision 21.pdf`
# - Hình giải thích: folder `giai-thich-ch2/` (01→21)
# - Gantt: `deadline-gantt-nhomE-ch2.png`
# - Script tạo hình: `gen_ch2_hinh.py`
