# %% [markdown]
# # Phân chia công việc — Nhóm D (UTH)
#
# **File này chỉ để XEM phân công — không code ở đây.**
#
# **Làm bài + nộp:** mở [`bai_tap_thuc_hanh_xu_ly_anh_3-2.ipynb`](./bai_tap_thuc_hanh_xu_ly_anh_3-2.ipynb) và viết code trực tiếp trong file đó.
#
# Thành viên: Duy · Tuyền · Trường · Nguyên · Nhung · Quyến · **Deadline: 11:59 PM 19/5**
#
# **Repo nhóm:** https://github.com/rosdev29/UTH-CV-BaiTap
# **Bài này nằm trong:** `Chapter1/` (repo sau này thêm `Chapter2/`, …)
#
# **Lý thuyết bắt buộc:** [`Computer_Vision 19.pdf`](./Computer_Vision%2019.pdf) — mọi người code theo công thức trong PDF, không bịa hoặc gọi hàm có sẵn cho phần phải tự viết.

# %% [markdown]
# ## Git — Nhánh theo phần việc
#
# **Tên nhánh = phần làm**, không đặt tên người. Ai push thì GitHub/Git vẫn hiện **tài khoản người push**; trong commit ghi rõ `Tên: việc đã làm` (vd. `Duy: pad_binary_image_manual`).
#
# **Chỉ sửa** `bai_tap_thuc_hanh_xu_ly_anh_3-2.ipynb` trên nhánh của phần mình.
#
# ### Tên nhánh gợi ý
#
# | Người | Nhánh (ví dụ) |
# |-------|----------------|
# | Duy | `bai-1/padding-structuring-element` |
# | Tuyền | `bai-1/erosion-dilation` |
# | Trường | `bai-1/opening-closing-gradient` |
# | Nguyên | `bai-2/interpolation-convolve` |
# | Nhung | `bai-2/warp-ssaa` |
# | Quyến | `bai-2/bicubic-lanczos` |
# | Tuyền + Trường | `bai-1/thi-nghiem-nhan-xet` |
# | Nhung + Quyến | `bai-2/ghep-warp-demo-nhan-xet` |
#
# Có thể rút gọn (vd. `bai-1-padding-se`) miễn **cả nhóm hiểu cùng một quy ước**.
#
# ### Clone (lần đầu)
#
# ```bash
# git clone https://github.com/rosdev29/UTH-CV-BaiTap.git
# cd UTH-CV-BaiTap/Chapter1
# git checkout -b <ten-nhanh-trong-bang-tren>
# ```
#
# Làm bài trong folder **`Chapter1/`**, không đặt file lẻ ở root repo.
#
# ### Mỗi lần ngồi code
#
# ```bash
# git checkout main
# git pull origin main
# git checkout <ten-nhanh-phan-viec-cua-ban>
# git merge main
# ```
#
# Sửa `bai_tap_thuc_hanh_xu_ly_anh_3-2.ipynb` → lưu:
#
# ```bash
# git add Chapter1/bai_tap_thuc_hanh_xu_ly_anh_3-2.ipynb
# git commit -m "Duy: pad_binary_image_manual, make_structuring_element"
# git push -u origin <ten-nhanh-phan-viec-cua-ban>
# ```
#
# (Chạy lệnh `git add` từ **root** repo `UTH-CV-BaiTap`, hoặc `add` đường dẫn tương đối từ chỗ đang đứng.)
#
# **Commit message:** `Tên: mô tả ngắn phần đã làm` — đủ để tra lịch sử, không cần đặt nhánh theo tên.
#
# ### Gộp vào `main`
#
# 1. GitHub: **Pull request** — nhánh phần việc → `main`.
# 2. **Duy (leader)** review và **merge** PR vào `main`.
# 3. Thứ tự merge gợi ý: padding → erosion → opening → interpolation → warp → bicubic → các nhánh làm chung.
# 4. Sau merge: mọi người `git pull origin main` rồi `git merge main` trên nhánh mình.
#
# ### Tránh conflict `.ipynb`
#
# - Chỉ sửa hàm/ô phần mình.
# - **Pull + merge `main` trước khi làm.**
# - Conflict: báo nhóm, không xóa code người khác.
#
# ### Trước nộp (19/5)
#
# - `main` chạy được cả notebook · **Trường + Quyến** tick checklist · nộp `bai_tap_thuc_hanh_xu_ly_anh_3-2.ipynb`.

# %% [markdown]
# ## Việc từng người
#
# Trong file làm bài: `Ctrl+F` **tên hàm** (cột bên phải).
#
# | Người | Việc | Tìm trong `bai_tap_...ipynb` |
# |-------|------|------------------------------|
# | **Duy** | Padding + phần tử cấu trúc | `pad_binary_image_manual`, `make_structuring_element` |
# | **Tuyền** | Erosion + dilation | `erosion_binary`, `dilation_binary` |
# | **Trường** | Opening, closing, gradient | `opening_binary`, `closing_binary`, `morphological_gradient_binary` |
# | **Nguyên** | Nearest, bilinear, convolve | `nearest_interpolate`, `bilinear_interpolate`, `convolve2d_manual` |
# | **Nhung** | Warp + SSAA | `warp_affine_manual`, `warp_affine_ssaa` |
# | **Quyến** | Bicubic + Lanczos | `bicubic_interpolate`, `lanczos_interpolate`, `cubic_kernel`, `lanczos_kernel` |
#
# → Chi tiết công thức PDF: xem mục **Tra cứu PDF — từng người** ngay bên dưới.

# %% [markdown]
# ## Tra cứu PDF — từng người
#
# File: [`Computer_Vision 19.pdf`](./Computer_Vision%2019.pdf) (cùng folder `Chapter1/`).
#
# | Người | Mục PDF | Việc của bạn | Nhắc khi code |
# |-------|---------|--------------|---------------|
# | **Duy** | **§1.1** | `pad_binary_image_manual`, `make_structuring_element` | SE ma trận 0/1; pad `constant` → 0; rectangle / cross / ellipse |
# | **Tuyền** | **§1.2–1.3** | `erosion_binary`, `dilation_binary` | Co: \(\min\) trên cửa sổ B (mọi ô SE=1 phải là tiền cảnh); Giãn: \(\max\). Ảnh notebook dùng **0/255** — chuẩn hóa tương đương 0/1 trước khi min/max |
# | **Trường** | **§1.4–1.5** | `opening_binary`, `closing_binary`, `morphological_gradient_binary` | Mở = co → giãn; Đóng = giãn → co; Gradient = giãn − co. Dùng hàm Tuyền + SE của Duy |
# | **Nguyên** | **§2.1**, **§3.2–3.3** | `nearest_interpolate`, `bilinear_interpolate`, `convolve2d_manual` | Tích chập cố định (§2.1); nearest = làm tròn (§3.3); bilinear = trọng số \(\delta_r,\delta_c\) (§3.3) |
# | **Nhung** | **§3.1**, **§3.4** | `warp_affine_manual`, `warp_affine_ssaa` | Warp **ngược** \(M^{-1}\); ngoài biên → `fill_value`; SSAA = trung bình \(L^2\) mẫu hoặc box \(L\times L\) + `convolve2d_manual` (§3.4) |
# | **Quyến** | **§3.5–3.6** | `cubic_kernel`, `bicubic_interpolate`, `lanczos_kernel`, `lanczos_interpolate` | Bicubic Keys \(a=-0.5\); Lanczos = sinc cửa sổ. Kernel **đổi theo** \(\delta\) từng pixel — **không** gọi `convolve2d_manual` một lần cho cả ảnh (§3.2) |
#
# **Làm chung:** Tuyền + Trường thử nghiệm theo hiệu ứng §1.4 (mở/đóng); Nhung + Quyến so sánh anti-aliasing theo bảng §3 (nearest / bilinear / SSAA / bicubic / Lanczos).

# %% [markdown]
# ## Làm chung — ô cụ thể trong `bai_tap_...ipynb`
#
# Mở file bài tập → `Ctrl+F` **đúng dòng** dưới đây (copy nguyên).
#
# ### Tuyền + Trường (Bài 1)
#
# | Ai | Việc | Tìm bằng `Ctrl+F` |
# |----|------|-------------------|
# | **Tuyền** | Bỏ comment, chạy thử nghiệm (opening, erosion, …) | `# Ô thực hành gợi ý` |
# | **Trường** | Viết nhận xét từng kết quả hình thái học | **Thêm 1 ô Markdown mới** ngay **dưới** ô `# Ô thực hành gợi ý` (file gốc **không** có ô nhận xét Bài 1 sẵn) |
#
# Ô `# Ô thực hành gợi ý` nằm **ngay sau** ô code có chữ `# TODO: Sinh viên tự hoàn thiện các phép toán hình thái học`, **trước** heading `# Bài tập 2`.
#
# **Lưu ý:** Tuyền và Trường cùng sửa **một ô code** chứa `erosion_binary` … `morphological_gradient_binary` — chia theo hàm, tránh sửa cùng lúc; merge Git cẩn thận.
#
# ### Nhung + Quyến (Bài 2)
#
# | Ai | Việc | Tìm bằng `Ctrl+F` |
# |----|------|-------------------|
# | **Nhung** | Ghép `bicubic`/`lanczos` vào `warp_affine_manual` + chạy demo | `# Ô thực hành so sánh anti-aliasing` |
# | **Quyến** | Trả lời 4 câu hỏi (đọc mục `### So sánh và nhận xét` phía trên) | `Sinh viên viết nhận xét so sánh ở đây` |
#
# Thứ tự trong file (từ trên xuống): markdown **So sánh và nhận xét** (4 câu hỏi) → ô code demo → ô markdown nhận xét.
#
# ### Trường + Quyến (trước nộp)
#
# | Việc | Tìm bằng `Ctrl+F` |
# |------|-------------------|
# | Tick checklist | `# Checklist trước khi nộp bài` |

# %% [markdown]
# ## Phụ thuộc (đọc code người trước)
#
# | Bạn | Cần xong phần của |
# |-----|-------------------|
# | Tuyền | Duy |
# | Trường | Duy, Tuyền |
# | Nhung | Nguyên |
# | Quyến | Nguyên (lướt Nhung khi ghép warp) |

# %% [markdown]
# ## Lịch gợi ý (16/5 → 19/5)
#
# | Ngày | Việc |
# |------|------|
# | **16/5** | Cả nhóm đọc đề + chạy setup trong file bài tập · **Duy**, **Nguyên** xong nền |
# | **17/5** | **Tuyền**, **Trường**, **Nhung**, **Quyến** xong code riêng |
# | **18/5** | Phần làm chung · chạy thử **cả** `bai_tap_thuc_hanh_xu_ly_anh_3-2.ipynb` |
# | **19/5** | Sửa lỗi · checklist · **nộp** file bài tập |
#
# Git: xem mục **Nhánh theo phần việc** · commit `Tên: việc đã làm`.

# %% [markdown]
# ## Cả nhóm đọc
#
# 1. **`Computer_Vision 19.pdf`** — mục tương phần việc của mình (bảng **Tra cứu PDF** phía trên)
# 2. Trong `bai_tap_...ipynb`: thiết lập chung + ảnh kiểm thử
# 3. Yêu cầu **Bài 1** (SE: rectangle, cross, ellipse)
# 4. Yêu cầu **Bài 2** + ràng buộc (không `cv2.warpAffine`, không convolve có sẵn, …)
# 5. Checklist cuối file
